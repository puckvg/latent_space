# %%
import pandas
import tools

# %%
df = pandas.read_csv("../poo.csv", sep = "\t", index_col=0)

# %%
im_freqs = df.loc["imaginary_frequency_count", :]

# %%
im_freqs
# Out:
# dsC7O2H10nsd_0001    1.0
# dsC7O2H10nsd_0002    2.0
# dsC7O2H10nsd_0003    2.0
# dsC7O2H10nsd_0004    2.0
# dsC7O2H10nsd_0005    4.0
#                     ...
# dsC7O2H10nsd_6091    2.0
# dsC7O2H10nsd_6092    3.0
# dsC7O2H10nsd_6093    3.0
# dsC7O2H10nsd_6094    3.0
# dsC7O2H10nsd_6095    4.0
# Name: imaginary_frequency_count, Length: 6095, dtype: float64

# %%
# append to qm9_properties

# %%
df_total = pandas.read_csv("../qm9_properties.csv", sep= "\t", index_col=0)

# %%
df_all = df_total.append(im_freqs)
df_all
# Out:
#                           dsC7O2H10nsd_0001   dsC7O2H10nsd_0002  \
# ID
# A                                   3.15804             3.18389
# B                                   1.24363             1.17376
# C                                   1.10602              1.0523
# mu                                   1.1312              1.4619
# alpha                                 77.92               76.64
# homo                               -0.21236            -0.22287
# lumo                                0.02396             0.01851
# gap                                 0.23632             0.24138
# r2                                1176.6995           1210.2333
# zpve                               0.157714            0.158126
# u0                              -423.060648          -423.05829
# u                               -423.051482         -423.049306
# h                               -423.050538         -423.048361
# g                               -423.094516         -423.091847
# ...

# %%
df_all.to_csv("../qm9_properties.csv")
