# %%
import pandas
import tools
from rdkit import Chem

# %%
df = pandas.read_csv("../qm9_properties.csv", sep = "\t", index_col=0)
df
# Out:
#                           dsC7O2H10nsd_0001 dsC7O2H10nsd_0002  \
# ID
# A                                   3.15804           3.18389
# B                                   1.24363           1.17376
# C                                   1.10602            1.0523
# mu                                   1.1312            1.4619
# alpha                                 77.92             76.64
# homo                               -0.21236          -0.22287
# lumo                                0.02396           0.01851
# gap                                 0.23632           0.24138
# r2                                1176.6995         1210.2333
# zpve                               0.157714          0.158126
# u0                              -423.060648        -423.05829
# u                               -423.051482       -423.049306
# h                               -423.050538       -423.048361
# g                               -423.094516       -423.091847
# cv                                   34.695            34.434
# imaginary_frequencies                    []                []
# imaginary_frequency_count                 0                 0
#
#                           dsC7O2H10nsd_0003   dsC7O2H10nsd_0004  \
# ID
# A                                   2.48409             2.42825
# B                                   1.31168             1.50237
# C                                    1.0558             0.97394
# mu                                   1.6032               1.165
# alpha                                 78.88               78.88
# homo                               -0.19589             -0.2137
# lumo                                 0.0248             0.01582
# gap                                 0.22069             0.22952
# r2                                1226.8962           1221.2049
# zpve                               0.158053            0.158338
# u0                               -423.05914         -423.061194
# u                               -423.049643         -423.051893
# h                               -423.048698         -423.050949
# g                               -423.093848          -423.09572
# cv                                   34.719              34.394
# imaginary_frequencies                    []  [-9.6009, -8.8096]
# imaginary_frequency_count                 0                   2
#
#                           dsC7O2H10nsd_0005 dsC7O2H10nsd_0006  \
# ID
# A                                   2.53802           4.03195
# B                                    1.4141           0.92243
# C                                    0.9537           0.89742
# mu                                   1.0674            1.9674
# alpha                                 78.38             78.88
# homo                               -0.21149          -0.19836
# lumo                                0.01679           0.02641
# gap                                 0.22828           0.22477
# r2                                1237.6017         1389.1963
# zpve                                0.15842          0.158147
# u0                              -423.062407       -423.059519
# u                               -423.053191       -423.050129
# h                               -423.052247       -423.049185
# g                               -423.096619       -423.093925
# cv                                   34.327             34.72
# imaginary_frequencies             [-8.0319]                []
# imaginary_frequency_count                 1                 0
#
#                              dsC7O2H10nsd_0007            dsC7O2H10nsd_0008  \
# ID
# A                                      4.13816                      3.18147
# B                                      0.91811                      1.06469
# C                                      0.89008                      0.95596
# mu                                      1.6934                       1.8513
# alpha                                    79.36                        79.77
# homo                                  -0.21689                     -0.21153
# lumo                                   0.01767                      0.01646
# gap                                    0.23456                      0.22799
# r2                                   1410.1485                    1327.4894
# zpve                                  0.158133                     0.158025
# u0                                 -423.063056                  -423.067098
# u                                  -423.053603                  -423.057648
# h                                  -423.052658                  -423.056704
# g                                  -423.097722                  -423.101781
# cv                                      34.524                       34.488
# imaginary_frequencies      [-11.1798, -4.1967]  [-15.6727, -9.3037, -6.141]
# imaginary_frequency_count                    2                            3
#
#                           dsC7O2H10nsd_0009   dsC7O2H10nsd_0010  ...  \
# ID                                                               ...
# A                                    3.6404             2.44905  ...
# B                                    0.9393             1.33561  ...
# C                                   0.87684             0.98126  ...
# mu                                   1.8809              1.5814  ...
# alpha                                 79.16               77.41  ...
# homo                               -0.21648            -0.21916  ...
# lumo                                0.01663             0.02141  ...
# gap                                 0.23311             0.24057  ...
# r2                                1411.4237           1245.4641  ...
# zpve                               0.157899            0.158481  ...
# u0                              -423.062491         -423.059202  ...
# u                               -423.052926         -423.049948  ...
# h                               -423.051982         -423.049004  ...
# g                               -423.097369         -423.093339  ...
# cv                                   34.665              34.282  ...
# imaginary_frequencies                    []  [-9.7941, -3.9246]  ...
# imaginary_frequency_count                 0                   2  ...
#
#                             dsC7O2H10nsd_6086             dsC7O2H10nsd_6087  \
# ID
# A                                     4.54947                      10.32299
# B                                     0.66709                       0.40723
# C                                     0.61021                       0.39564
# mu                                     1.9551                         4.039
# alpha                                   80.74                         86.24
# homo                                 -0.24933                      -0.26742
# lumo                                  0.04525                      -0.06164
# gap                                   0.29458                       0.20578
# r2                                  1802.2355                     2674.3428
# zpve                                 0.156526                      0.155331
# u0                                -422.960601                    -422.99364
# u                                 -422.950742                   -422.982684
# h                                 -422.949798                    -422.98174
# g                                 -422.996384                    -423.03193
# cv                                     35.717                        35.861
# imaginary_frequencies      [-7.8267, -2.8069]  [-23.8498, -3.0263, -2.9368]
# imaginary_frequency_count                   2                             3
#
#                              dsC7O2H10nsd_6088             dsC7O2H10nsd_6089  \
# ID
# A                                      7.48376                       6.62241
# B                                       0.4239                       0.41594
# C                                      0.40523                       0.39521
# mu                                      3.2065                        4.7163
# alpha                                    85.88                         85.79
# homo                                  -0.26496                      -0.26273
# lumo                                  -0.05957                      -0.05822
# gap                        0.20538999999999996           0.20451000000000003
# r2                                   2599.7765                     2643.6079
# zpve                                  0.155652                      0.155596
# u0                                 -423.000391                   -422.994312
# u                                  -422.989451                   -422.983254
# h                                  -422.988507                    -422.98231
# g                                  -423.039114                    -423.03433
# cv                                      35.799                        35.765
# imaginary_frequencies                [-3.8722]  [-22.9704, -5.3287, -3.7631]
# imaginary_frequency_count                    1                             3
#
#                                       dsC7O2H10nsd_6090 dsC7O2H10nsd_6091  \
# ID
# A                                               6.60065           4.85264
# B                                               0.40092           0.61445
# C                                               0.38152           0.60579
# mu                                               2.9762            1.7586
# alpha                                             84.92             80.81
# homo                                            -0.2631           -0.2777
# lumo                                           -0.05774          -0.03994
# gap                                             0.20536           0.23776
# r2                                            2686.7824         1903.3517
# zpve                                           0.156039          0.156383
# u0                                          -423.002431       -423.026195
# u                                           -422.991394       -423.015836
# h                                            -422.99045       -423.014892
# g                                           -423.041659       -423.062926
# cv                                                36.25            35.963
# imaginary_frequencies      [-21.6848, -4.4359, -4.3182]         [-9.4504]
# imaginary_frequency_count                             3                 1
#
#                              dsC7O2H10nsd_6092 dsC7O2H10nsd_6093  \
# ID
# A                                      3.47085           5.50702
# B                                      0.69233           0.56013
# C                                      0.58562           0.51491
# mu                                      3.0221            1.8302
# alpha                                     79.8             80.99
# homo                                  -0.26541          -0.25572
# lumo                                  -0.06072          -0.05846
# gap                        0.20468999999999998           0.19726
# r2                                   1875.9981         2098.4143
# zpve                                  0.154691          0.154879
# u0                                 -422.994107       -422.999749
# u                                  -422.984173       -422.989014
# h                                  -422.983228        -422.98807
# g                                  -423.030202       -423.037185
# cv                                       34.57            36.558
# imaginary_frequencies      [-19.6859, -3.3749]         [-7.5163]
# imaginary_frequency_count                    2                 1
#
#                              dsC7O2H10nsd_6094    dsC7O2H10nsd_6095
# ID
# A                                      3.58197              3.55635
# B                                       0.6187              0.58477
# C                                      0.55163              0.52594
# mu                                      3.1284               3.3964
# alpha                                    80.34                79.46
# homo                                  -0.25921             -0.25977
# lumo                                  -0.05824             -0.05959
# gap                        0.20096999999999998              0.20018
# r2                                   1977.0369            2026.1917
# zpve                                  0.155393             0.155862
# u0                                 -422.992835          -423.000502
# u                                  -422.982116          -422.989787
# h                                  -422.981172          -422.988843
# g                                  -423.030557          -423.038286
# cv                                      36.262               36.752
# imaginary_frequencies       [-6.5445, -4.3976]  [-12.9677, -7.8892]
# imaginary_frequency_count                    2                    2
#
# [17 rows x 6095 columns]

# %%
im_freqs = df.loc["imaginary_frequency_count", :]

# %%
im_freqs
# Out:
# dsC7O2H10nsd_0001    0
# dsC7O2H10nsd_0002    0
# dsC7O2H10nsd_0003    0
# dsC7O2H10nsd_0004    2
# dsC7O2H10nsd_0005    1
#                     ..
# dsC7O2H10nsd_6091    1
# dsC7O2H10nsd_6092    2
# dsC7O2H10nsd_6093    1
# dsC7O2H10nsd_6094    2
# dsC7O2H10nsd_6095    2
# Name: imaginary_frequency_count, Length: 6095, dtype: object

# %% [markdown]
# ## Plot graph of im freqs

# %%
ax = im_freqs.value_counts().sort_index().plot.bar()
ax.set_xlabel("Number of imaginary frequencies")
ax.set_ylabel("Number of molecules")
# Out:
# Text(0, 0.5, 'Number of molecules')

# %% [markdown]
# ## Write lists to files

# %%
zero_molecules = im_freqs[im_freqs==0].index.tolist()
zero_molecules
# Out:
# []

# %%
for i in range(4):
    label = str(i) + "_frequencies"
    list_molecules = im_freqs[im_freqs==i].index.tolist()
    tools.write_list_to_file(list_molecules, label + ".txt")

# %% [markdown]
# ## Produce grid images of some molecules in each list

# %%
# see https://www.rdkit.org/docs/GettingStartedInPython.html under
# "drawing molecules"
# Input: SDF/ smiles 
# for mol in mols: tmp = AllChem.Compute2DCoords(mol)
# Chem.Draw.MolsToGridImage(mols, molsPerRow=x)
# or w substructure match 
# backbone = mol
# submols = [x for x in mols if x.HasSubStructMatch(backbone)]
# for mol in submols: AllChem.GenerateDepictionMatching2DStructure(mol,backbone)
# img = Draw.MolsToGridImage(submols, molsPerRow=x)
# img.save("bla.png")
